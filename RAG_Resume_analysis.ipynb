# %%
import os
import anthropic
import PyPDF2
import json
import pandas as pd

# %%
def load_env_from_json(file_path):
    """Loads security keys from a JSON file and sets them as environment variables."""
    try:
        with open(file_path, 'r') as file:
            secrets = json.load(file)
            for key, value in secrets.items():
                os.environ[key] = value
                print(f"Loaded {key} into environment variables")  # Optional, for debugging
    except FileNotFoundError:
        print(f"Error: The file {file_path} was not found.")
    except json.JSONDecodeError:
        print(f"Error: Could not parse {file_path}. Ensure it is valid JSON.")

# %%
load_env_from_json('secrets.json')
# Out:
# Loaded ANTHROPIC_API_KEY into environment variables

# %%
def extract_text_from_pdf(pdf_path):
    """
    Extracts text from a PDF file.
    """
    text = ""
    with open(pdf_path, "rb") as pdf_file:
        reader = PyPDF2.PdfReader(pdf_file)
        for page in reader.pages:
            text += page.extract_text() + "\n"
    return text.strip()

# %%
def keywords_extraction_prompt(model):
    system_prompt = ""
    if model == "CLAUDE":
        system_prompt = """
            You are an AI text analysis expert specializing in job market intelligence. Carefully analyze the following job description to extract the MOST SIGNIFICANT keywords that would be valuable for resume tailoring and job market analysis.
            Categorize and extract keywords in these specific areas:
            1. TECHNICAL REQUIREMENTS:
               - Hard skills (specific proficiencies)
               - Technologies/programming languages/frameworks
               - Software/platforms/tools
               - Technical certifications/qualifications        
            2. EXPERIENCE & EXPERTISE:
               - Years of experience
               - Domain expertise
               - Industry-specific knowledge
               - Required credentials/education
                    3. JOB RESPONSIBILITIES:
               - Core functions
               - Key deliverables
               - Project management aspects
               - Performance metrics mentioned
            4. PROFESSIONAL ATTRIBUTES:
               - Soft skills
               - Communication styles
               - Collaboration approaches
               - Leadership requirements
            5. COMPANY & INDUSTRY CONTEXT:
               - Industry terminology
               - Business domain vocabulary
               - Company-specific jargon
               - Market positioning indicators
            For each category, list only the 5-7 most critical terms that would significantly impact application success. Prioritize specialized terms over generic ones. Format your response as comma-separated values within each category.
            """
    elif model == "CHATGPT":
        system_prompt = """
            You are an AI assistant specializing in job description analysis. Your task is to extract **only the most relevant and high-impact keywords** from the given job description.
            
            Focus on keywords that are essential for understanding the job role, filtering out generic terms. The extracted keywords should be valuable for **resume matching, candidate profiling, and industry trend analysis**.
            
            #### **Categories to Extract Keywords From:**
            - **Core Skills & Expertise**: Technical and domain-specific skills required for the role.
            - **Tools, Technologies, & Frameworks**: Programming languages, software, methodologies, and platforms used in the job.
            - **Key Responsibilities**: Actionable tasks, duties, and role expectations.
            - **Soft Skills**: Essential interpersonal and workplace competencies.
            - **Industry-Specific Terminology**: Jargon, compliance requirements, certifications, and any sector-related terminology.
            
            #### **Response Format:**
            Return the extracted keywords as a **concise, comma-separated list**, prioritizing **high-value terms** that best describe the job role.
            """    
    return system_prompt

# %%
def execute_question(system_prompt, user_message):
    client = anthropic.Anthropic(api_key=ANTHROPIC_API_KEY)
    response = client.messages.create(
        model="claude-3-7-sonnet-20250219",
        max_tokens=1000,
        temperature=0.3,
        system=system_prompt,
        messages=[{"role": "user", "content": user_message}]
    )
    return response.content

# %%
def execute_question2(system_prompt, user_message):
    client = anthropic.Anthropic(api_key=ANTHROPIC_API_KEY)
    response = client.messages.create(
        model="claude-3-7-sonnet-20250219",
        max_tokens=1000,
        temperature=0.3,
        system=system_prompt,
        messages=[{"role": "user", "content": user_message}]
    )
    
    # Extract the text from the first content block
    if response.content and len(response.content) > 0:
        # Remove markdown headers and leading/trailing whitespace
        clean_text = response.content[0].text.replace('# About Me\n\n', '').strip()
        return clean_text
    
    return ""  # Return empty string if no content

# %%
def get_keywords(job_description, model):
    system_prompt = keywords_extraction_prompt(model)    
    user_message = f"""
        Job Description:
        ---
        {job_description}
        ---
        """
    question_response = execute_question(system_prompt, user_message)
    return question_response

# %%
# Set your API key
ANTHROPIC_API_KEY = os.getenv("ANTHROPIC_API_KEY")
# Path where the JD is stored
PDF_DIR = "JD_PATH"
# Name of the JD file
FILE_NAME = "jd_sample.pdf"
jd_path = PDF_DIR + FILE_NAME
# Options for the prompt to use, I got them from 2 different platforms
# CLAUDE | CHATGPT
use_prompt = "CLAUDE"
# Resume PDF
PDF_RESUME_DIR = "PATH_OF_RESUME_PDF"
PDF_RESUME_NAME = "personalresume.PDF"

# %%
RESUME_DIR = "PATH_OF_RESUME_JSON"
RESUME_NAME = "personal_resume.json"
resume_path = RESUME_DIR + RESUME_NAME
pdf_path = PDF_RESUME_DIR + PDF_RESUME_NAME

# %%
jd_text = extract_text_from_pdf(jd_path)
resume_text = extract_text_from_pdf(pdf_path)

if jd_text:
    keywords = get_keywords(jd_text, use_prompt)
    print("\nExtracted Keywords:\n", keywords)
else:
    print("Could not extract text from the PDF.")
# Out:
# Extracted Keywords:
#  [TextBlock(text="## KEYWORD ANALYSIS\n\n### 1. TECHNICAL REQUIREMENTS:\nTechnical project management, Agile, Scrum, Lean, Kanban, JIRA, Datadog, Confluence, Slack, cloud technologies, SDLC process methods, system architecture, technical frameworks\n\n### 2. EXPERIENCE & EXPERTISE:\n5+ years technical project management experience, Bachelor's degree in Computer Science/Engineering, project management certifications (PMP, PRINCE2, Certified Scrum Master), experience with marketplace-based business models, experience scaling products/systems\n\n### 3. JOB RESPONSIBILITIES:\nManaging high-priority projects, defining project scope/timeline/success criteria, identifying critical path dependencies, proactive risk identification, coordinating cross-functional teams, establishing metrics/reporting mechanisms, driving process improvements, ensuring QA sign-off\n\n### 4. PROFESSIONAL ATTRIBUTES:\nExceptional organizational skills, excellent verbal/written communication, problem-solving abilities, strong analytical mindset, results-driven approach, ability to adapt to changing priorities, operational mindset, execution ability\n\n### 5. COMPANY & INDUSTRY CONTEXT:\nMental health care, therapy services, product portfolio management, cross-functional collaboration, KPIs, business results, minimum viable products, remote work environment, cloud/mobile projects", type='text')]

# %%
def parse_resume_json(file_path):
    """
    Reads a JSON file containing resume sections and converts it into a Pandas DataFrame.
    
    :param file_path: Path to the JSON file
    :return: Pandas DataFrame
    """
    with open(file_path, "r", encoding="utf-8") as file:
        data = json.load(file)

    # Extract relevant fields
    rows = []
    for section in data["resume_sections"]:
        rows.append({
            "section_name": section.get("section_name", ""),
            "action": section.get("action", ""),
            "rules": "\n".join(section.get("rules", [])),
            "section_text": section.get("section_text", "")
        })

    # Convert to DataFrame
    df = pd.DataFrame(rows)
    
    return df

# %%
def parse_resume_json_dynamic(file_path):
    """
    Reads a JSON file containing resume sections and converts it into a Pandas DataFrame.
    
    :param file_path: Path to the JSON file
    :return: Pandas DataFrame
    """
    with open(file_path, "r", encoding="utf-8") as file:
        data = json.load(file)
    
    # Extract relevant fields
    rows = []
    for section in data["resume_sections"]:
        # Prepare a dictionary to store section data
        section_data = {
            "section_name": section.get("section_name", ""),
            "action": section.get("action", ""),
            "rules": "\n".join(section.get("rules", [])),
            "section_text_header": section.get("section_text_header", "")
        }
        
        # Dynamically collect bullet points
        bullets = []
        for i in range(1, 8):  # Check for up to 7 bullet points
            bullet_key = f"section_text_bullet{i}"
            if bullet_key in section:
                bullets.append(section[bullet_key])
        
        # Join bullets into a single text
        section_data["section_text_bullets"] = "\n".join(bullets)
        
        rows.append(section_data)
    
    # Convert to DataFrame
    df = pd.DataFrame(rows)
    
    return df

# %%
df = parse_resume_json_dynamic(resume_path)

# %%
# Iterate through all rows
for index, row in df.iterrows():
    if row["section_name"] == "cover_letter":
        system_prompt = "Action:" + row['action'] + "\n Rules:" + row['rules'] + "\n Keywords:"  + ', '.join(str(x) for x in keywords) + "\n COMPLETE RESUME:" + resume_text
        user_message = "Job Description:" + jd_text 
        print("#" * 50)  # Separator for better readability
        response = execute_question2(system_prompt, user_message)
        print(row["section_name"])
        print(response)
        print("#" * 50)  # Separator for better readability
    else:
        system_prompt = "Action:" + row['action'] + "\n Rules:" + row['rules'] + "\n Keywords:"  + ', '.join(str(x) for x in keywords)
        user_message = row['section_text_header'] + row["section_text_bullets"]
        response = execute_question2(system_prompt, user_message)
        print(row["section_name"])
        print(response)
        print("-" * 50)  # Separator for better readability
# Out:
# about
# I've updated your "about" section to align with the Product Manager role at Infosys, incorporating relevant keywords from the job description:
#
# Strategic Technical Program Manager with 5+ years experience leading enterprise data platforms and digital transformation initiatives. Expertise in Agile/Scrum methodologies, JIRA, and full SDLC processes while driving cross-functional engineering teams across Media & Entertainment and Retail industries. Proven track record in project scope definition, risk identification, and establishing metrics for success. Consistently deliver multimillion-dollar cost savings through innovative technical solutions and process improvements. Core strengths in stakeholder management, vendor partnerships, and scaling products/systems with an operational, results-driven mindset.
# --------------------------------------------------
# skills_section
# ## Skills
#
# **Leadership:** Product Management | Agile Framework | Cross-functional Team Leadership | Technical Project Management
#
# **Strategic:** Technical Architecture | Change Management | Process Optimization | Data Analytics | AI/Machine Learning | System Scaling | Marketplace Business Models
#
# **Operational:** Agile/Scrum | Lean | Kanban | Platform Integration | Risk Management | Vendor Management | SDLC Process Methods
#
# **PM Methodologies & Tools:** Agile/Hybrid Methodologies | Scrum | JIRA | Confluence | Slack | Datadog | MS-Project | Smartsheet | Notion
#
# **Technical:** Data Engineering | AI/Machine Learning | Business Intelligence | Cloud Technologies | Technical Frameworks
# --------------------------------------------------
# motortrend_experience
# Led enterprise-wide data engineering initiatives and managed cross-functional teams while driving strategic technical programs for digital and streaming platforms.
#
# A) Led cross-functional quarterly planning and prioritization across Data Engineering, Product, QA, and BI teams, managing resources and timelines for 7 platform teams while aligning stakeholder expectations from technical to C-level.
#
# B) Redesigned data-driven processes through 'Situation Rooms' methodology, increasing ticket resolution speed by 300% and team productivity metrics (50% more story points, 37% higher ticket completion) via custom analytics dashboards and improved requirement gathering.
#
# C) Built strategic relationships with key vendors (mParticle, Amplitude, Snowflake) while managing technical integrations, enhancements roadmap, and identifying cost optimization resulting in $50K savings.
#
# D) Spearheaded design and implementation of innovative Nitrous Heads-Up Display (HUD) system providing real-time performance metrics, reducing time-to-insight from days to minutes, delivering $45K annual savings, and increasing editorial team efficiency.
#
# E) Led portfolio of high-priority projects: CDP integration across 7 platforms ($750K savings, 1500+ tickets), Snowflake migration (60% faster processing), One Identity platform merger, and major product launches including Car Finder and Next.js website migration.
#
# F) Established metrics and reporting mechanisms through a data quality framework with Python and Snowflake that reduced inconsistencies by 75%, implementing automated validation pipelines and real-time KPI dashboards.
#
# G) Coordinated cross-functional teams for strategic platform integrations with Warner Bros. Discovery, managing technical requirements and compliance for SVOD content, user authentication, and data privacy across enterprise systems.
# --------------------------------------------------
# sony_experience
# I've analyzed your work experience and will align it with the key requirements for a technical project management role, maintaining your original structure:
#
# Led digital product operations and SVOD platform initiatives across global markets, managing cross-functional teams and implementing scalable technical solutions.
#
# A) Orchestrated launch of Crackle SVOD platforms across 17 countries, managing technical integration for 65 affiliates across OTT, TVE, and STB platforms while ensuring multi-language support and security compliance.
#
# B) Led optimization of VOD operations through data-driven analysis, implementing Agile, Scrum and Kanban methodologies that reduced delivery time by 40% and improved team velocity by 35% across 7 regional markets.
#
# C) Designed and implemented real-time content publication monitoring system with automated checkpoints and KPI dashboards in JIRA, establishing metrics that increased operational efficiency by 35%.
#
# D) Built and led QA team, implementing SDLC process methods and JIRA workflows that improved content certification speed by 50% while maintaining 99.9% accuracy and ensuring proper QA sign-off.
#
# E) Developed scalable security workflows for cloud-based platform integration, proactively identifying risks and enabling secure content delivery across multiple distribution channels with zero security incidents.
#
# F) Led a team of 5 Technical Project Managers distributed across the LATAM region, coordinating cross-functional teams and driving process improvements through the product lifecycle.
# --------------------------------------------------
# sears_experience
# Led digital transformation of merchandising operations through implementation of new technologies and data-driven processes.
# - Managed high-priority projects implementing an enterprise purchasing platform for 500+ users, utilizing Agile/Scrum methodologies to deliver automated workflows that reduced processing time by 40%
# - Designed integration framework connecting legacy systems with modern platforms, coordinating cross-functional teams to enable real-time inventory tracking across 100+ stores
# - Developed scalable supply chain solution supporting 200+ vendors, establishing metrics that demonstrated 45% reduction in transaction processing costs
# - Collaborated with C-level executives to define digital strategy and ROI-driven solutions, identifying critical path dependencies and proactively managing risks
# - Led a team of 5 Engineers specialized in web development, database management and backend systems, ensuring QA sign-off and driving process improvements
# --------------------------------------------------
# sts_experience
# I'll align your work experience with the job description keywords:
#
# Delivered strategic technology solutions for major retail and financial enterprises in Mexico.
# - Led technical project management for centralized web platform integrating 6 legacy systems, applying Agile/Scrum methodologies to enable real-time data synchronization across 18 retail stores, reducing operational costs by 35%.
# - Managed cross-functional teams in digital transformation for TV ad sales platform at Azteca, establishing clear metrics and KPIs that resulted in 25% revenue growth through automated inventory and billing processes.
# - Directed SDLC processes for enterprise platforms serving major clients (Scotia Bank, ANTAD, Zurich, Sony), defining project scope and critical path dependencies that delivered 12 successful launches with 40% improvement in user engagement.
# - Implemented data-driven project governance framework with proactive risk identification, improving project delivery time by 30% while maintaining 98% stakeholder satisfaction.
# --------------------------------------------------
# ##################################################
# cover_letter
# # Cover Letter - Gerardo Tapia Cruz
#
# Dear Hiring Manager,
#
# I am excited to apply for the Senior Technical Project Manager position at BetterHelp. As a Technical Program Manager with extensive experience leading enterprise platforms and digital transformation initiatives, I am eager to contribute to your mission of making mental health care more accessible worldwide.
#
# ## Technical Project Management Experience
# With over 5 years of technical project management experience at Warner Bros. Discovery and Sony Pictures, I've successfully implemented Agile methodologies across cross-functional teams. I've led quarterly planning and prioritization across Data Engineering, Product, QA, and BI teams while managing resources and timelines for multiple platform teams. My experience with JIRA, Confluence, and other project management tools has enabled me to create structure and predictability in complex environments.
#
# ## Project Execution & Delivery
# Throughout my career, I've managed high-priority projects with clear scope, timelines, and success criteria. At MotorTrend, I spearheaded a portfolio of high-complexity initiatives including CDP integration across 7 platforms, Snowflake migration, and major product launches. I consistently identify critical path dependencies and develop mitigation strategies to keep projects on track, as demonstrated by my 300% increase in ticket resolution speed through redesigned data-driven processes.
#
# ## Technical Aptitude & System Architecture
# My background in Computer Science and data engineering provides me with strong technical understanding of platforms, architecture, and integrations. I've architected data quality frameworks, led platform integrations, and designed integration frameworks connecting legacy systems with modern platforms. This technical foundation helps me effectively support teams in overcoming technical challenges.
#
# ## Cross-Functional Collaboration
# I excel at coordinating cross-functional teams and serving as a central point of communication. At Sony, I orchestrated the launch of SVOD platforms across 17 countries, managing technical integration for 65 affiliates while ensuring multi-language support and security compliance. I've built strategic relationships with key vendors while managing technical integrations and roadmaps.
#
# ## Process Improvement & Metrics
# I'm passionate about establishing clear metrics and driving process improvements. I've implemented custom analytics dashboards that improved team productivity metrics by 50% more story points and 37% higher ticket completion. At Sony, my implementation of Agile methodologies and automated workflows reduced delivery time by 40% and improved team velocity by 35%.
#
# I am drawn to BetterHelp's mission and culture, particularly your commitment to employee well-being and professional development. I believe my technical project management expertise, combined with my results-driven approach and strong analytical mindset, would make me a valuable addition to your team.
#
# Thank you for considering my application. I look forward to discussing how I can contribute to BetterHelp's continued growth and success.
#
# Sincerely,
# Gerardo Tapia Cruz
# ##################################################
